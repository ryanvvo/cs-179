# %%
import sys
import os
sys.path.append(os.path.abspath('models'))

from model_util import *
from simple_linear import *

import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import pyro, torch, signal
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import os

# %%
payload = load_model("linear-classifier")

meta = payload['meta']

print(meta.keys())
print(meta['training_acc'])

epochs = [f for f in range(1, payload['epoch'] + 1)]

#get only the second element of each tuple in training_acc
training_acc = [(acc[1] * 0.01) for acc in meta['training_acc']]

#plot training accuracy accross epochs
plt.plot(epochs, training_acc, label='Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy')
plt.legend()
plt.show()
# Out:
#  model loaded <- saved_models\linear-classifier.pt  (epoch 200)
# dict_keys(['training_acc', 'testing_acc', 'loss'])
# ...

# %%
payload = load_model("naive-bayes-model")

meta = payload['meta']

print(meta.keys())
print(meta['training_acc'])

epochs = [f for f in range(1, payload['epoch'] + 1)]

#get only the second element of each tuple in training_acc
training_acc = [(acc[1] * 0.01) for acc in meta['training_acc']]

#plot training accuracy accross epochs
plt.plot(epochs, training_acc, label='Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy')
plt.legend()
plt.show()
# Out:
#  model loaded <- saved_models\naive-bayes-model.pt  (epoch 200)
# dict_keys(['training_acc', 'testing_acc', 'loss'])
# ...

# %%
payload = load_model("deep-belief-network")

meta = payload['meta']

print(meta.keys())
print(meta['training_acc'])

epochs = [f for f in range(1, payload['epoch'] + 1)]

#get only the second element of each tuple in training_acc
training_acc = [(acc[1] * 0.01) for acc in meta['training_acc']]

#plot training accuracy accross epochs
plt.plot(epochs, training_acc, label='Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy')
plt.legend()
plt.show()
# Out:
#  model loaded <- saved_models\deep-belief-network.pt  (epoch 200)
# dict_keys(['training_acc', 'testing_acc', 'loss'])
# ...

# %%
payload = load_model("restricted-boltzmann-model")

meta = payload['meta']

print(meta.keys())
print(meta['training_acc'])

epochs = [f for f in range(1, payload['epoch'] + 1)]

#get only the second element of each tuple in training_acc
training_acc = [(acc[1] * 0.01) for acc in meta['training_acc']]

#plot training accuracy accross epochs
plt.plot(epochs, training_acc, label='Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy')
plt.legend()
plt.show()
